# %%
pip install geopandas
# Out:
# ...
#
#   Using cached geopandas-1.0.1-py3-none-any.whl.metadata (2.2 kB)
# ...
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
# Using cached geopandas-1.0.1-py3-none-any.whl (323 kB)
# ...
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    ------- -------------------------------- 2.4/12.9 MB 13.4 MB/s eta 0:00:01
#    ----------------- ---------------------- 5.5/12.9 MB 13.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 7.6/12.9 MB 12.7 MB/s eta 0:00:01
#    ------------------------------- -------- 10.2/12.9 MB 12.5 MB/s eta 0:00:01
#    ---------------------------------------  12.8/12.9 MB 12.6 MB/s eta 0:00:01
#    ---------------------------------------- 12.9/12.9 MB 12.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#    --------- ------------------------------ 2.9/11.6 MB 14.0 MB/s eta 0:00:01
# ...

# %%
pip install pysal
# Out:
# ...
#
#   Using cached pysal-24.7-py3-none-any.whl.metadata (16 kB)
# ...
#   Using cached beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# ...
#   Using cached scipy-1.14.1-cp311-cp311-win_amd64.whl.metadata (60 kB)
# ...
#   Using cached scikit_learn-1.5.1-cp311-cp311-win_amd64.whl.metadata (12 kB)
# ...
#   Using cached libpysal-4.12.1-py3-none-any.whl.metadata (4.8 kB)
# ...
#   Using cached access-1.1.9-py3-none-any.whl.metadata (2.4 kB)
# ...
#   Using cached esda-2.6.0-py3-none-any.whl.metadata (2.0 kB)
# ...
#   Using cached giddy-2.3.5-py3-none-any.whl.metadata (6.4 kB)
# ...
#   Using cached inequality-1.0.1-py3-none-any.whl.metadata (3.3 kB)
# ...
#   Using cached pointpats-2.5.0-py3-none-any.whl.metadata (4.7 kB)
# ...
#   Using cached segregation-2.5-py3-none-any.whl.metadata (2.2 kB)
# ...
#   Using cached spaghetti-1.7.6-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached mgwr-2.2.1-py3-none-any.whl.metadata (1.5 kB)
# ...
